# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r'D:\projects\fooddeliverytime\notebook\data\finalTrain.csv')

# %%
df.head()
# Out:
#        ID Delivery_person_ID  Delivery_person_Age  Delivery_person_Ratings
# 0  0xcdcd      DEHRES17DEL01                 36.0                      4.2  \
# 1  0xd987      KOCRES16DEL01                 21.0                      4.7
# 2  0x2784     PUNERES13DEL03                 23.0                      4.7
# 3  0xc8b6     LUDHRES15DEL02                 34.0                      4.3
# 4  0xdb64      KNPRES14DEL02                 24.0                      4.7
#
#    Restaurant_latitude  Restaurant_longitude  Delivery_location_latitude
# 0            30.327968             78.046106                   30.397968  \
# 1            10.003064             76.307589                   10.043064
# 2            18.562450             73.916619                   18.652450
# 3            30.899584             75.809346                   30.919584
# 4            26.463504             80.372929                   26.593504
#
#    Delivery_location_longitude  Order_Date Time_Orderd Time_Order_picked
# ...

# %%
df['Festival'].unique()
# Out:
# array(['No', 'Yes', nan], dtype=object)

# %%
df_copy = df.copy()

# %%
df_copy = df_copy.drop(labels=['ID', 'Delivery_person_ID'],axis=1)
df_copy.head()
# Out:
#    Delivery_person_Age  Delivery_person_Ratings  Restaurant_latitude
# 0                 36.0                      4.2            30.327968  \
# 1                 21.0                      4.7            10.003064
# 2                 23.0                      4.7            18.562450
# 3                 34.0                      4.3            30.899584
# 4                 24.0                      4.7            26.463504
#
#    Restaurant_longitude  Delivery_location_latitude
# 0             78.046106                   30.397968  \
# 1             76.307589                   10.043064
# 2             73.916619                   18.652450
# 3             75.809346                   30.919584
# 4             80.372929                   26.593504
#
#    Delivery_location_longitude  Order_Date Time_Orderd Time_Order_picked
# 0                    78.116106  12-02-2022       21:55             22:10  \
# 1                    76.347589  13-02-2022       14:55             15:05
# ...

# %%
df_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45584 entries, 0 to 45583
# Data columns (total 18 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Delivery_person_Age          43730 non-null  float64
#  1   Delivery_person_Ratings      43676 non-null  float64
#  2   Restaurant_latitude          45584 non-null  float64
#  3   Restaurant_longitude         45584 non-null  float64
#  4   Delivery_location_latitude   45584 non-null  float64
#  5   Delivery_location_longitude  45584 non-null  float64
#  6   Order_Date                   45584 non-null  object
#  7   Time_Orderd                  43853 non-null  object
#  8   Time_Order_picked            45584 non-null  object
#  9   Weather_conditions           44968 non-null  object
#  10  Road_traffic_density         44983 non-null  object
#  11  Vehicle_condition            45584 non-null  int64
# ...

# %%
## Missing Values
df_copy.isnull().sum()
# Out:
# Delivery_person_Age            1854
# Delivery_person_Ratings        1908
# Restaurant_latitude               0
# Restaurant_longitude              0
# Delivery_location_latitude        0
# Delivery_location_longitude       0
# Order_Date                        0
# Time_Orderd                    1731
# Time_Order_picked                 0
# Weather_conditions              616
# Road_traffic_density            601
# Vehicle_condition                 0
# Type_of_order                     0
# Type_of_vehicle                   0
# multiple_deliveries             993
# Festival                        228
# City                           1200
# Time_taken (min)                  0
# dtype: int64

# %% [markdown]
# There is no null value

# %%
df_copy['Delivery_person_Age'] = df_copy['Delivery_person_Age'].fillna(df_copy['Delivery_person_Age'].mean())

# %%
df_copy['Delivery_person_Age'].unique()
# Out:
# array([36.        , 21.        , 23.        , 34.        , 24.        ,
#        29.        , 35.        , 33.        , 25.        , 31.        ,
#        37.        , 27.        , 32.        , 26.        , 38.        ,
#        20.        , 22.        , 29.56691059, 28.        , 39.        ,
#        30.        , 15.        , 50.        ])

# %%
df_copy['Delivery_person_Ratings']  = df_copy['Delivery_person_Ratings'].fillna(df_copy['Delivery_person_Ratings'].mean())
df_copy['Delivery_person_Ratings'].unique()
# Out:
# array([4.2      , 4.7      , 4.3      , 4.5      , 4.       , 4.9      ,
#        4.1      , 5.       , 4.8      , 3.5      , 4.6      , 4.6337737,
#        4.4      , 3.8      , 3.9      , 3.7      , 2.6      , 2.5      ,
#        3.6      , 3.1      , 2.7      , 1.       , 3.2      , 3.3      ,
#        6.       , 3.4      , 2.8      , 2.9      , 3.       ])

# %%
df_copy['Weather_conditions']  = df_copy['Weather_conditions'].fillna('Fog')
df_copy['Weather_conditions'].value_counts()
# Out:
# Weather_conditions
# Fog           8269
# Stormy        7584
# Cloudy        7533
# Sandstorms    7494
# Windy         7422
# Sunny         7282
# Name: count, dtype: int64

# %%
df_copy['Road_traffic_density'].value_counts()
# Out:
# Road_traffic_density
# Low       15476
# Jam       14139
# Medium    10945
# High       4423
# Name: count, dtype: int64

# %%
df_copy['Road_traffic_density']  = df_copy['Road_traffic_density'].fillna('Low')
df_copy['Road_traffic_density'].value_counts()
# Out:
# Road_traffic_density
# Low       16077
# Jam       14139
# Medium    10945
# High       4423
# Name: count, dtype: int64

# %%
df_copy['multiple_deliveries'] = df_copy['multiple_deliveries'].fillna(df_copy['multiple_deliveries'].median())

# %%
df_copy['multiple_deliveries'].value_counts()
# Out:
# multiple_deliveries
# 1.0    29144
# 0.0    14094
# 2.0     1985
# 3.0      361
# Name: count, dtype: int64

# %%
df_copy['Festival'].value_counts()
# Out:
# Festival
# No     44460
# Yes      896
# Name: count, dtype: int64

# %%
df_copy['Festival']  = df_copy['Festival'].fillna('No')
df_copy['Festival'].value_counts()
# Out:
# Festival
# No     44688
# Yes      896
# Name: count, dtype: int64

# %%
df_copy['City'].value_counts()
# Out:
# City
# Metropolitian    34087
# Urban            10133
# Semi-Urban         164
# Name: count, dtype: int64

# %%
df_copy['City']  = df_copy['City'].fillna('Metropolitian')
df_copy['City'].value_counts()
# Out:
# City
# Metropolitian    35287
# Urban            10133
# Semi-Urban         164
# Name: count, dtype: int64

# %%
df_copy.isnull().sum()
# Out:
# Delivery_person_Age               0
# Delivery_person_Ratings           0
# Restaurant_latitude               0
# Restaurant_longitude              0
# Delivery_location_latitude        0
# Delivery_location_longitude       0
# Order_Date                        0
# Time_Orderd                    1731
# Time_Order_picked                 0
# Weather_conditions                0
# Road_traffic_density              0
# Vehicle_condition                 0
# Type_of_order                     0
# Type_of_vehicle                   0
# multiple_deliveries               0
# Festival                          0
# City                              0
# Time_taken (min)                  0
# dtype: int64

# %%
R = 6371  ##The earth's radius (in km)

def deg_to_rad(degrees):
    return degrees * (np.pi/180)

## The haversine formula
def distcalculate(lat1, lon1, lat2, lon2):
    d_lat = deg_to_rad(lat2-lat1)
    d_lon = deg_to_rad(lon2-lon1)
    a1 = np.sin(d_lat/2)**2 + np.cos(deg_to_rad(lat1))
    a2 = np.cos(deg_to_rad(lat2)) * np.sin(d_lon/2)**2
    a = a1 * a2
    c = 2 * np.arctan2(np.sqrt(a), np.sqrt(1-a))
    return R * c

# Create distance column & calculate the distance
df_copy['distance'] = np.nan

for i in range(len(df_copy)):
  df_copy.loc[i, 'distance'] = distcalculate(df_copy.loc[i, 'Restaurant_latitude'], 
                                          df_copy.loc[i, 'Restaurant_longitude'], 
                                          df_copy.loc[i, 'Delivery_location_latitude'], 
                                          df_copy.loc[i, 'Delivery_location_longitude'])

# %% [markdown]
# The parameter “lat” means latitude, and “lon” means longitude. The deg_to_rad function is helpful for converting degrees to radians. At the same time, calculate the distance between two location points using the variables a1 and a2. The variable stores the result of multiplying a1 and a2, while the c variable stores the result of the Haversine formula calculation, which produces the distance between the two location points.
#
# We have added a distance column to the dataset. Now, we will analyze the effect of distance and delivery time.

# %% [markdown]
# We drop the columns Restaurant_latitude, Restaurant_longitude,	Delivery_location_latitude,	Delivery_location_longitude

# %%
df_copy = df_copy.drop(labels=['Restaurant_latitude',	'Restaurant_longitude',	'Delivery_location_latitude',	'Delivery_location_longitude'],axis=1)
df_copy.head()
# Out:
#    Delivery_person_Age  Delivery_person_Ratings  Order_Date Time_Orderd
# 0                 36.0                      4.2  12-02-2022       21:55  \
# 1                 21.0                      4.7  13-02-2022       14:55
# 2                 23.0                      4.7  04-03-2022       17:30
# 3                 34.0                      4.3  13-02-2022       09:20
# 4                 24.0                      4.7  14-02-2022       19:50
#
#   Time_Order_picked Weather_conditions Road_traffic_density
# 0             22:10                Fog                  Jam  \
# 1             15:05             Stormy                 High
# 2             17:40         Sandstorms               Medium
# 3             09:30         Sandstorms                  Low
# 4             20:05                Fog                  Jam
#
#    Vehicle_condition Type_of_order Type_of_vehicle  multiple_deliveries
# 0                  2         Snack      motorcycle                  3.0  \
# ...

# %%
df_copy['distance'].value_counts()
# Out:
# distance
# 14.455331       341
# 2.223898        337
# 6.671695        336
# 10.007540       336
# 4.447797        335
#                ...
# 17525.745838      1
# 6.594054          1
# 14.372945         1
# 3.316391          1
# 17231.954219      1
# Name: count, Length: 4791, dtype: int64

# %% [markdown]
# There were some datas which is like 17525 km it was a problem that generate by distance_calculator I fill up these with median.

# %%
dist_median=df_copy['distance'].median()
dist_median
# Out:
# 6.364367766222553

# %%
for i in range(len(df_copy['distance'])):
    if (df_copy['distance'][i]>100):
        df_copy['distance'][i]=dist_median

# %%
df_copy['Order_Date']=pd.to_datetime(df_copy['Order_Date'],dayfirst=True)

# %%
df_copy['Day']=df_copy['Order_Date'].dt.day
df_copy['Month']=df_copy['Order_Date'].dt.month
df_copy['Year']=df_copy['Order_Date'].dt.year

# %%
df_copy = df_copy.drop(labels=['Order_Date'],axis=1)

# %%
df_copy['Time_Order_Hour']=df_copy['Time_Order_picked'].astype(str).str.split(':').str[0]
df_copy['Time_Order_Min']=df_copy['Time_Order_picked'].astype(str).str.split(':').str[1]

# %%
df_copy['Time_Order_Hour']=df_copy['Time_Order_Hour'].astype('float')
df_copy['Time_Order_Min']=df_copy['Time_Order_Min'].astype('float')

# %%
df_copy.head()
# Out:
#    Delivery_person_Age  Delivery_person_Ratings Weather_conditions
# 0                 36.0                      4.2                Fog  \
# 1                 21.0                      4.7             Stormy
# 2                 23.0                      4.7         Sandstorms
# 3                 34.0                      4.3         Sandstorms
# 4                 24.0                      4.7                Fog
#
#   Road_traffic_density  Vehicle_condition Type_of_order Type_of_vehicle
# 0                  Jam                  2         Snack      motorcycle  \
# 1                 High                  1          Meal      motorcycle
# 2               Medium                  1        Drinks         scooter
# 3                  Low                  0        Buffet      motorcycle
# 4                  Jam                  1         Snack         scooter
#
#    multiple_deliveries Festival           City  Time_taken (min)   distance
# ...

# %% [markdown]
# I am taking density of traffic so I think time of order has no significent effect

# %% [markdown]
# Check dulicates

# %%
dupl=df_copy[df_copy.duplicated()]
dupl
# Out:
# Empty DataFrame
# Columns: [Delivery_person_Age, Delivery_person_Ratings, Weather_conditions, Road_traffic_density, Vehicle_condition, Type_of_order, Type_of_vehicle, multiple_deliveries, Festival, City, Time_taken (min), distance, Day, Month, Year, Time_Order_Hour, Time_Order_Min]
# Index: []

# %% [markdown]
# There is no duplicate so i leave this

# %%
## Segregated numeric and cotegorical column

numeric_columns=df_copy.columns[df_copy.dtypes!='object']
categorical_columns=df_copy.columns[df_copy.dtypes=='object']

print("Numerical coumns: ",numeric_columns)
print("Categorical coumns: ",categorical_columns)
# Out:
# Numerical coumns:  Index(['Delivery_person_Age', 'Delivery_person_Ratings', 'Vehicle_condition',
#        'multiple_deliveries', 'Time_taken (min)', 'distance', 'Day', 'Month',
#        'Year', 'Time_Order_Hour', 'Time_Order_Min'],
#       dtype='object')
# Categorical coumns:  Index(['Weather_conditions', 'Road_traffic_density', 'Type_of_order',
#        'Type_of_vehicle', 'Festival', 'City'],
#       dtype='object')

# %%
df_copy[categorical_columns].describe()
# Out:
#        Weather_conditions Road_traffic_density Type_of_order Type_of_vehicle
# count               45584                45584         45584           45584  \
# unique                  6                    4             4               4
# top                   Fog                  Low         Snack      motorcycle
# freq                 8269                16077         11530           26429
#
#        Festival           City
# count     45584          45584
# unique        2              3
# top          No  Metropolitian
# freq      44688          35287

# %% [markdown]
# Univarient plot for Numeric_columns

# %%
plt.figure(figsize=(10,5))
x=0
for i in numeric_columns:
    sns.histplot(data=df_copy,x=i,kde=True)
    print('\n')
    plt.show()

# %% [markdown]
# univarient count plot for categorical_columns

# %%
plt.figure(figsize=(8,5))
x=0
for i in categorical_columns:
    sns.countplot(data=df_copy,x=df[i])
    print('\n')
    plt.show()

# %% [markdown]
# Bivarient plot for categorical data with delivery time

# %%
sns.barplot(data=df_copy,x='Time_Order_Hour',y='Time_taken (min)')
# Out:
# <Axes: xlabel='Time_Order_Hour', ylabel='Time_taken (min)'>

# %%
x=0
for i in categorical_columns:
    plt.figure(figsize=(8,5))
    sns.barplot(data=df_copy,x=df[i],y='Time_taken (min)')
    print('\n')
    plt.show()

# %% [markdown]
# Bar plot of variable 'type of order' has no effect on delivery time. So we can drop this variable.

# %% [markdown]
# Bivarient plot for numerical data with delivery time

# %%
x=0
for i in numeric_columns:
    plt.figure(figsize=(15,5))
    sns.barplot(data=df_copy,x=i, y='Time_taken (min)')
    print('\n')
    plt.show()

# %%
sns.pairplot(df_copy)

# %%
df_copy['Weather_conditions'].unique()
# Out:
# array(['Fog', 'Stormy', 'Sandstorms', 'Windy', 'Cloudy', 'Sunny'],
#       dtype=object)

# %%
Weather_conditions_map = {'Fog':5, 'Stormy':27, 'Sandstorms':26, 'Windy':2, 'Cloudy':3, 'Sunny':1}

# %%
df_copy['Road_traffic_density'].unique()
# Out:
# array(['Jam', 'High', 'Medium', 'Low'], dtype=object)

# %%
Road_traffic_density_map = {'Jam':1, 'High':4, 'Medium':3, 'Low':2}

# %%
df_copy['Type_of_order'].unique()
# Out:
# array(['Snack', 'Meal', 'Drinks', 'Buffet'], dtype=object)

# %%
Type_of_order_map = {'Snack':2, 'Meal':3, 'Drinks':1, 'Buffet':4}

# %%
df_copy['Type_of_vehicle'].unique()
# Out:
# array(['motorcycle', 'scooter', 'electric_scooter', 'bicycle'],
#       dtype=object)

# %%
Type_of_vehicle_map = {'motorcycle':4, 'scooter':3, 'electric_scooter':2, 'bicycle':1}

# %%
df_copy['Festival'].unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
Festival_map = {'No':0, 'Yes':1}

# %%
df_copy['City'].unique()
# Out:
# array(['Metropolitian', 'Urban', 'Semi-Urban'], dtype=object)

# %%
City_map = {'Metropolitian':1, 'Urban':3, 'Semi-Urban':2}

# %%
df_copy['Weather_conditions']=df_copy['Weather_conditions'].replace(Weather_conditions_map)
df_copy['Road_traffic_density']=df_copy['Road_traffic_density'].replace(Road_traffic_density_map)
df_copy['Type_of_order']=df_copy['Type_of_order'].replace(Type_of_order_map)
df_copy['Type_of_vehicle']=df_copy['Type_of_vehicle'].replace(Type_of_vehicle_map)
df_copy['Festival']=df_copy['Festival'].replace(Festival_map)
df_copy['City']=df_copy['City'].replace(City_map)
df_copy.head()
# Out:
#    Delivery_person_Age  Delivery_person_Ratings  Weather_conditions
# 0                 36.0                      4.2                   5  \
# 1                 21.0                      4.7                  27
# 2                 23.0                      4.7                  26
# 3                 34.0                      4.3                  26
# 4                 24.0                      4.7                   5
#
#    Road_traffic_density  Vehicle_condition  Type_of_order  Type_of_vehicle
# 0                     1                  2              2                4  \
# 1                     4                  1              3                4
# 2                     3                  1              1                3
# 3                     2                  0              4                4
# 4                     1                  1              2                3
#
#    multiple_deliveries  Festival  City  Time_taken (min)   distance  Day
# ...

# %%
##correlation
plt.figure(figsize=(10,10))
sns.heatmap(df_copy.corr(),annot=True)
# Out:
# <Axes: >
